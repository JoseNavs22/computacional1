# %%
def vectorfield(w, t, p):
    """
    Definimos las ecuaciones diferenciales para el sistema de doble masa-resorte.
    Arguments:
        w : Vector del estado de las variables 
                  w = [x1,y1,x2,y2]
        t :  Tiempo
        p :  Vector de los parametros:
                  p = [m1,m2,k1,k2,L1,L2,b1,b2]
    """
    x1, y1, x2, y2 = w
    m1, m2, k1, k2, L1, L2, b1, b2 = p

    #Creamos f = (x1',y1',x2',y2')
    f = [y1,
         (-b1 * y1 - k1 * (x1 - L1) + k2 * (x2 - x1 - L2)) / m1,
         y2,
         (-b2 * y2 - k2 * (x2 - x1 - L2)) / m2]
    return f

# %%
from scipy.integrate import odeint

# Masas:
m1 = 1.0
m2 = 1.0
# Constante del resorte
k1 = 0.4
k2 = 1.808
# Longitudes naturales
L1 = 0
L2 = 0
# Coeficientes de fricción
b1 = 0.0
b2 = 0.0

# Condiciones iniciales
x1 = 0.5
y1 = 0.0
x2 = -0.5
y2 = 0.7

# Parametros de la ED
abserr = 1.0e-8
relerr = 1.0e-6
stoptime = 50.0
numpoints = 250

t = [stoptime * float(i) / (numpoints - 1) for i in range(numpoints)]

p = [m1, m2, k1, k2, L1, L2, b1, b2]
w0 = [x1, y1, x2, y2]

wsol = odeint(vectorfield, w0, t, args=(p,),
              atol=abserr, rtol=relerr)

with open('dosresortes2_3.dat', 'w') as f:
    for t1, w1 in zip(t, wsol):
        print (t1, w1[0], w1[1], w1[2], w1[3],file=f)

# %%
from numpy import loadtxt
from pylab import figure, plot, xlabel, grid, hold, legend, title, savefig, ylabel
from matplotlib.font_manager import FontProperties
import matplotlib.pyplot as plt
# %matplotlib inline

t, x1, xy, x2, y2 = loadtxt('dosresortes2_3.dat', unpack=True)

figure(1, figsize=(6, 4.5))

grid(True)
lw = 1

plt.plot(x1,xy, 'purple', linewidth=lw, label="x1")
plt.axhline(0, color='black',linewidth=0.5)
plt.axvline(0, color='black',linewidth=0.5)
x = [-2, -1,0,1,2]
y = [-2, -1,0,1,2]
plt.xticks(x)
plt.yticks(y)

title('Retrato de fase para x1')
savefig('Ej2_31.png', dpi=100)

# %%
# %matplotlib inline

t, x1, xy, x2, y2 = loadtxt('dosresortes2_3.dat', unpack=True)

figure(1, figsize=(6, 4.5))

grid(True)
lw = 1

plt.plot(x2,y2, 'turquoise', linewidth=lw, label="x2")
plt.axhline(0, color='black',linewidth=0.5)
plt.axvline(0, color='black',linewidth=0.5)
x = [-2, -1,0,1,2]
y = [-2, -1,0,1,2]
plt.xticks(x)
plt.yticks(y)

title('Retrato de fase para x2')
savefig('Ej2_32.png', dpi=100)

# %%
# %matplotlib inline

t, x1, xy, x2, y2 = loadtxt('dosresortes2_3.dat', unpack=True)

figure(1, figsize=(6, 4.5))

xlabel('t')
ylabel('x')
grid(True)
lw = 1.5

plot(t, x1, 'purple', linewidth=lw)
plt.axhline(0, color='black',linewidth=0.5)
plt.axvline(0, color='black',linewidth=0.5)
y = [-2, -1,0,1,2]
plt.yticks(y)

title('Posición de las Masas para\nel Sistema Doble Resorte-Masa de x1')
savefig('Ej2_33.png', dpi=100)

# %%
# %matplotlib inline

t, x1, xy, x2, y2 = loadtxt('dosresortes2_3.dat', unpack=True)

figure(1, figsize=(6, 4.5))

xlabel('t')
ylabel('x')
grid(True)
lw = 1.5

plot(t, x2, 'turquoise', linewidth=lw)
plt.axhline(0, color='black',linewidth=0.5)
plt.axvline(0, color='black',linewidth=0.5)
y = [-2, -1,0,1,2]
plt.yticks(y)

title('Posición de las Masas para\nel Sistema Doble Resorte-Masa de x2')
savefig('Ej2_34.png', dpi=100)

# %%
# %matplotlib inline

t, x1, xy, x2, y2 = loadtxt('dosresortes2_3.dat', unpack=True)

figure(1, figsize=(6, 4.5))

xlabel('t')
ylabel('x')
grid(True)
lw = 1.5

plot(t, x1, 'purple', linewidth=lw)
plot(t, x2, 'turquoise', linewidth=lw)
plt.axhline(0, color='black',linewidth=0.5)
plt.axvline(0, color='black',linewidth=0.5)
y = [-2, -1,0,1,2]
plt.yticks(y)

legend((r'$x_1$', r'$x_2$'), prop=FontProperties(size=16))
title('Posición de las Masas para\nel Sistema Doble Resorte-Masa')
savefig('Ej2_35.png', dpi=100)

# %%
# %matplotlib inline

t, x1, xy, x2, y2 = loadtxt('dosresortes2_3.dat', unpack=True)

figure(1, figsize=(6, 4.5))

grid(True)
lw = 1.5

plot(x1,x2, 'teal', linewidth=lw)
plt.axhline(0, color='black',linewidth=0.5)
plt.axvline(0, color='black',linewidth=0.5)

title('Gráfica x1 vs x2')
savefig('Ej2_36.png', dpi=100)
