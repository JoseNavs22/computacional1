# %%
import pandas as pd
import numpy as np
from datetime import datetime

# %%
#Leemos los datos y cambiamos el CAPE  a numerico.
df00 = pd.read_csv("df2017CAPE_PW_00Z.csv", header=None, names=['Date', 'CAPE', 'PW'])
df00.CAPE=pd.to_numeric(df00.CAPE, errors='coerce')
df00.head()
# Out:
#          Date  CAPE     PW
# 0  01 01 2017   0.0  18.79
# 1  02 01 2017   0.0   4.26
# 2  03 01 2017   0.0   5.38
# 3  04 01 2017   0.0   6.14
# 4  05 01 2017   0.0   5.73

# %%
df00.dtypes
# Out:
# Date     object
# CAPE    float64
# PW      float64
# dtype: object

# %%
# Convertimos el objeto de fecha a fecha.
df00['Ndate'] = pd.to_datetime(df00['Date'], format='%d %m %Y')
df00['month'] = df00['Ndate'].dt.month
df00.head()
# Out:
#          Date  CAPE     PW      Ndate  month
# 0  01 01 2017   0.0  18.79 2017-01-01      1
# 1  02 01 2017   0.0   4.26 2017-01-02      1
# 2  03 01 2017   0.0   5.38 2017-01-03      1
# 3  04 01 2017   0.0   6.14 2017-01-04      1
# 4  05 01 2017   0.0   5.73 2017-01-05      1

# %%
#Graficamos la grafica de caja de cada mes contra el CAPE para 00Z
import seaborn as sns
import matplotlib.pyplot as plt
ax = sns.boxplot(x="month", y="CAPE", data=df00)
plt.show()

# %%
#Graficamos la grafica de caja de cada mes contra el PW para 00Z
import seaborn as sns
import matplotlib.pyplot as plt
ax = sns.boxplot(x="month", y="PW", data=df00)
plt.show()

# %%
#Graficamos la grafica jointplot para 00Z, la de arriba muestra la distribución de CAPE, y la de derecha es DE PW
import seaborn as sns
sns.set(style="darkgrid", color_codes=True)

g = sns.jointplot("CAPE", "PW", data=df00, kind="reg",
                   color="r", size=7)
plt.show(g)

# %%
#Graficamos la grafica de correclación entre ambos datos
g = sns.lmplot(x="CAPE", y="PW", hue="month",
               truncate=True, size=5, data=df00)
plt.show(g)

# %%
df12 = pd.read_csv("df2017CAPE_PW_12Z.csv", header=None, names=['Date', 'CAPE', 'PW'])
df12.head()
# Out:
#          Date  CAPE     PW
# 0  01 01 2017   6.1   8.20
# 1  02 01 2017   0.0   5.21
# 2  03 01 2017   0.0   4.67
# 3  04 01 2017   0.0   5.68
# 4  05 01 2017   0.0  18.07

# %%
df12.dtypes
# Out:
# Date     object
# CAPE    float64
# PW      float64
# dtype: object

# %%
# Convertir la cadena de caracteres 'Date' en variable temporal 'NDate'
df12['Ndate'] = pd.to_datetime(df12['Date'], format='%d %m %Y')
df12['month'] = df12['Ndate'].dt.month
df12.head()
# Out:
#          Date  CAPE     PW      Ndate  month
# 0  01 01 2017   6.1   8.20 2017-01-01      1
# 1  02 01 2017   0.0   5.21 2017-01-02      1
# 2  03 01 2017   0.0   4.67 2017-01-03      1
# 3  04 01 2017   0.0   5.68 2017-01-04      1
# 4  05 01 2017   0.0  18.07 2017-01-05      1

# %%
#Graficamos la grafica de caja de cada mes contra el CAPE para 12Z
import seaborn as sns
import matplotlib.pyplot as plt
ax = sns.boxplot(x="month", y="CAPE", data=df12)
plt.show()

# %%
#Graficamos la grafica de caja de cada mes contra el PW para 12Z
import seaborn as sns
import matplotlib.pyplot as plt
ax = sns.boxplot(x="month", y="PW", data=df12)
plt.show()

# %%
#Graficamos la grafica jointplot para 12Z, la de arriba muestra la distribución de CAPE, y la de derecha es DE PW
import seaborn as sns
sns.set(style="darkgrid", color_codes=True)

g = sns.jointplot("CAPE", "PW", data=df12, kind="reg",
                   color="r", size=7)
plt.show(g)

# %%
#Graficamos la grafica de correclación entre ambos datos
g = sns.lmplot(x="CAPE", y="PW", hue="month",
               truncate=True, size=5, data=df12)
plt.show(g)
